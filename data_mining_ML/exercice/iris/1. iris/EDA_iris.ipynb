# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import pingouin as pg

# %%
data = pd.read_csv("iris.csv")

flowers = {0: "setosa", 1: "virsicolor", 2: "virginica"}

data["target"] = data["target"].map(flowers)
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         target
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
data.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                object
# dtype: object

# %%
plt.figure(figsize=(10, 5))
plt.title("Missing Values\n")
sns.heatmap(data.isnull(), cbar=False)
plt.show()

data.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
plt.figure(figsize=(10, 5))
plt.title("Countplot for target\n")
sns.countplot(data=data, x="target")
plt.show()

data["target"].value_counts()
# Out:
# target
# setosa        50
# virsicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(data.select_dtypes(float)):
    plt.subplot(2, 2, i + 1)
    sns.kdeplot(data=data, x=col, fill=True)
plt.show()

data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(data.select_dtypes(float)):
    plt.subplot(2, 2, i + 1)
    sns.kdeplot(data=data, x=col, fill=True, hue="target")
plt.show()

display(
    data[["sepal length (cm)", "sepal width (cm)", "target"]]
    .groupby("target")
    .describe()
)
data[["petal length (cm)", "petal width (cm)", "target"]].groupby("target").describe()
# Out:
#            sepal length (cm)                                              \
#                        count   mean       std  min    25%  50%  75%  max
# target
# setosa                  50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# virginica               50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
# virsicolor              50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
#
#            sepal width (cm)
#                       count   mean       std  min    25%  50%    75%  max
# target
# setosa                 50.0  3.428  0.379064  2.3  3.200  3.4  3.675  4.4
# virginica              50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8
# virsicolor             50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
#            petal length (cm)                                               \
#                        count   mean       std  min  25%   50%    75%  max
# target
# setosa                  50.0  1.462  0.173664  1.0  1.4  1.50  1.575  1.9
# virginica               50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9
# virsicolor              50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
#
#            petal width (cm)
#                       count   mean       std  min  25%  50%  75%  max
# target
# setosa                 50.0  0.246  0.105386  0.1  0.2  0.2  0.3  0.6
# virginica              50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5
# virsicolor             50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(data.select_dtypes(float)):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(data=data, x="target", y=col, hue="target")
plt.show()

# %%
sns.pairplot(data=data, hue="target")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title("Correlation Links\n")
sns.heatmap(
    data.select_dtypes(float).corr(),
    vmin=-1,
    vmax=1,
    cmap="coolwarm",
    cbar=False,
    annot=True,
)
plt.show()

# %%
# Test normality
for col in data.select_dtypes(float):
    print(col)
    display(pg.normality(data=data, dv=col, group="target"))
    print("\n")

# Test homoscedasticity
for col in data.select_dtypes(float):
    print(col)
    display(pg.homoscedasticity(data=data, dv=col, group="target"))
    print("\n")
# Out:
# sepal length (cm)
#                    W      pval  normal
# setosa      0.977699  0.459528    True
# virsicolor  0.977836  0.464733    True
# virginica   0.971180  0.258325    True
# sepal width (cm)
#                    W      pval  normal
# setosa      0.971720  0.271526    True
# virsicolor  0.974133  0.337989    True
# virginica   0.967391  0.180904    True
# petal length (cm)
#                    W      pval  normal
# setosa      0.954977  0.054810    True
# virsicolor  0.966005  0.158483    True
# virginica   0.962186  0.109774    True
# petal width (cm)
#                    W          pval  normal
# setosa      0.799764  8.658421e-07   False
# virsicolor  0.947627  2.727822e-02   False
# virginica   0.959772  8.695745e-02    True
# sepal length (cm)
#               W      pval  equal_var
# levene  6.35272  0.002259      False
# sepal width (cm)
#                W      pval  equal_var
# levene  0.590212  0.555518       True
# petal length (cm)
#                 W          pval  equal_var
# levene  19.480339  3.128757e-08      False
# petal width (cm)
#                 W          pval  equal_var
# levene  19.892439  2.260520e-08      False

# %%
# Normality is ok but variance are not equals => welch anova
for col in data.select_dtypes(float):
    print(col)
    display(pg.welch_anova(data=data, dv=col, between="target"))
    print("\n")
# Out:
# sepal length (cm)
#    Source  ddof1      ddof2           F         p-unc       np2
# 0  target      2  92.211145  138.908285  1.505059e-28  0.618706
# sepal width (cm)
#    Source  ddof1      ddof2          F         p-unc       np2
# 0  target      2  97.401587  45.012035  1.432735e-14  0.400783
# petal length (cm)
#    Source  ddof1      ddof2            F         p-unc       np2
# 0  target      2  78.072955  1828.091945  2.693327e-66  0.941372
# petal width (cm)
#    Source  ddof1      ddof2            F         p-unc       np2
# 0  target      2  84.951254  1276.884565  4.138739e-64  0.928883

# %%
# Post hoc test with welch anova => games howell
for col in data.select_dtypes(float):
    print(col)
    display(pg.pairwise_gameshowell(data=data, dv=col, between="target"))
    print("\n")
# Out:
# sepal length (cm)
#            A           B  mean(A)  mean(B)   diff        se          T  \
# 0     setosa   virginica    5.006    6.588 -1.582  0.102819 -15.386196
# 1     setosa  virsicolor    5.006    5.936 -0.930  0.088395 -10.520986
# 2  virginica  virsicolor    6.588    5.936  0.652  0.115825   5.629165
#
#           df   pval    hedges
# 0  76.515867  0.001 -3.053629
# 1  86.538002  0.001 -2.088053
# 2  94.025486  0.001  1.117195
# sepal width (cm)
#            A           B  mean(A)  mean(B)   diff        se         T  \
# 0     setosa   virginica    3.428    2.974  0.454  0.070384  6.450349
# 1     setosa  virsicolor    3.428    2.770  0.658  0.069593  9.454976
# 2  virginica  virsicolor    2.974    2.770  0.204  0.063635  3.205761
#
#           df      pval    hedges
# 0  95.547235  0.001000  1.280172
# 1  94.697774  0.001000  1.876486
# 2  97.926827  0.005127  0.636233
# petal length (cm)
#            A           B  mean(A)  mean(B)   diff        se          T  \
# 0     setosa   virginica    1.462    5.552 -4.090  0.081823 -49.986186
# 1     setosa  virsicolor    1.462    4.260 -2.798  0.070849 -39.492719
# 2  virginica  virsicolor    5.552    4.260  1.292  0.102509  12.603779
#
#           df   pval    hedges
# 0  58.609395  0.001 -9.920532
# 1  62.139768  0.001 -7.837941
# 2  95.570435  0.001  2.501415
# petal width (cm)
#            A           B  mean(A)  mean(B)  diff        se          T  \
# 0     setosa   virginica    0.246    2.026 -1.78  0.041603 -42.785798
# 1     setosa  virsicolor    0.246    1.326 -1.08  0.031690 -34.080342
# 2  virginica  virsicolor    2.026    1.326  0.70  0.047862  14.625367
#
#           df   pval    hedges
# 0  63.122624  0.001 -8.491504
# 1  74.754695  0.001 -6.763771
# 2  89.043375  0.001  2.902630
