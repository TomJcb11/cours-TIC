# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if (
    __name__ == "__main__"
):  # this is a way to make sure that the code is only run when the script is run directly, not when it is imported
    print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # exo
#
# créer un petit programme de vetérinaire qui vous permet de gérer vos animaux
#
# - Vous pouvez entrer un nouvel animal (race, nom, age, couleur, .....)
# - Vous pouvez sortir un animal (seulement s'il est vacciné)
# - Vous pouvez vacciner un animal
# - Vous pouvez voir la liste des animaux (on doit savoir s'il est vacciné)

# %%
import datetime


class Animal:
    def __init__(self, name, species, birthdate, color, weight):
        self.name = name
        self.species = species
        self.birthdate = birthdate
        self.color = color
        self.weight = weight
        self.feed = 0

    def vaccine(self):
        self.vaccine = True
        print("Animal vaccinated")

    def feed(self):
        self.feed += 1
        print("Animal fed and happy")

    def return_animal(self):
        if self.vaccine and self.feed > 0:
            self.status = "out"
            self.realease_date = datetime.now()
            print("Animal realeased")
        else:
            print("Animal not ready to be realeased")
# Out:
# Animal not ready to be realeased
# Animal vaccinated
# Animal not ready to be realeased
